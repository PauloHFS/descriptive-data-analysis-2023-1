# %% [markdown]
# <a href="https://colab.research.google.com/github/PauloHFS/descriptive-data-analysis-2023-1/blob/main/Lab1a_Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Introdução ao Pandas (Parte 1)

# %% [markdown]
# ## Imports

# %%
import pandas as pd
import random

# %% [markdown]
# ## Estruturas Básicas

# %% [markdown]
#   * **`DataFrame`**: uma matriz / tabela, com linhas e colunas.
#   * **`Series`**: um vetor representando uma coluna. Um DataFrame pode conter uma ou várias Series, com seus respectivos nomes.

# %% [markdown]
# #### Criando uma `Series` a partir de uma `list`

# %%
s = pd.Series(['Campina Grande', 'Patos', 'Sousa'])
s
# Out:
# 0    Campina Grande
# 1             Patos
# 2             Sousa
# dtype: object

# %% [markdown]
# #### Criando um `DataFrame` a partir de um `dict` que mapeia `string` (nomes de colunas) às repectivas `Series`.
#
# Se os comprimentos não coincidem, as células são preechidas com [NA/NaN](http://pandas.pydata.org/pandas-docs/stable/missing_data.html)

# %%
# @title
nome_cidade = pd.Series(['Campina Grande', 'Patos', 'Sousa'])
populacao = pd.Series([399999, 1499999, 99777])

df_city = pd.DataFrame({ 'Nome da Cidade': nome_cidade, 'População': populacao })
df_city
# Out:
#    Nome da Cidade  População
# 0  Campina Grande     399999
# 1           Patos    1499999
# 2           Sousa      99777

# %% [markdown]
# #### Verificando / alterando os tipos de dados

# %%
df_city.dtypes
# Out:
# Nome da Cidade    object
# População          int64
# dtype: object

# %% [markdown]
# Usamos a função astype para mudar os tipos do `DataFrame`inteiro ou de `Series`específicas. Exemplos [neste link](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.astype.html).

# %% [markdown]
# #### É possível criar Dataframes de várias outras formas. Também é possível definir outros tipos de índices. Veja exemplos [aqui](https://www.tutorialspoint.com/python_pandas/python_pandas_dataframe.htm).
#
# #### **ATIVIDADE 1:** Crie um pequeno `DataFrame` (e imprima) utilizando outra estratégia (e.g., lista de listas, `dict` de string para lista) e definindo outros índices.

# %%
df_filmes = pd.DataFrame(data={
    "nome": ["Barbie", "Drive", "Velozes e Furiosos"],
    "nota": [random.randrange(0, 10) for i in range(0, 3)],
    "bilheteria": [random.randrange(int(10e3), int(10e9)) for i in range(0, 3)]
}, index=[f'rank {i}' for i in range(0, 3)])

df_filmes
# Out:
#                       nome  nota  bilheteria
# rank 0              Barbie     8   396093191
# rank 1               Drive     0  4418465286
# rank 2  Velozes e Furiosos     5   975640616

# %% [markdown]
# #### Criando um `DataFrame` a partir de um arquivo CSV (é o que é mais frequentemente realizado)
#
# A descrição do dataset que vamos baixar pode ser vista [aqui](https://www.kaggle.com/camnugent/california-housing-prices).

# %%
df_housing = pd.read_csv("https://download.mlcc.google.com/mledu-datasets/california_housing_train.csv", sep=",")
df_housing
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -114.31     34.19                15.0       5612.0          1283.0
# 1        -114.47     34.40                19.0       7650.0          1901.0
# 2        -114.56     33.69                17.0        720.0           174.0
# 3        -114.57     33.64                14.0       1501.0           337.0
# 4        -114.57     33.57                20.0       1454.0           326.0
# ...          ...       ...                 ...          ...             ...
# 16995    -124.26     40.58                52.0       2217.0           394.0
# 16996    -124.27     40.69                36.0       2349.0           528.0
# 16997    -124.30     41.84                17.0       2677.0           531.0
# 16998    -124.30     41.80                19.0       2672.0           552.0
# 16999    -124.35     40.54                52.0       1820.0           300.0
#
#        population  households  median_income  median_house_value
# 0          1015.0       472.0         1.4936             66900.0
# 1          1129.0       463.0         1.8200             80100.0
# 2           333.0       117.0         1.6509             85700.0
# 3           515.0       226.0         3.1917             73400.0
# 4           624.0       262.0         1.9250             65500.0
# ...           ...         ...            ...                 ...
# 16995       907.0       369.0         2.3571            111400.0
# 16996      1194.0       465.0         2.5179             79000.0
# 16997      1244.0       456.0         3.0313            103600.0
# 16998      1298.0       478.0         1.9797             85800.0
# 16999       806.0       270.0         3.0147             94600.0
#
# [17000 rows x 9 columns]

# %%
df_housing.shape
# Out:
# (17000, 9)

# %%
df_housing.dtypes
# Out:
# longitude             float64
# latitude              float64
# housing_median_age    float64
# total_rooms           float64
# total_bedrooms        float64
# population            float64
# households            float64
# median_income         float64
# median_house_value    float64
# dtype: object

# %% [markdown]
# ## Funções Úteis

# %% [markdown]
# #### Função `head()`

# %%
df_housing.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -114.31     34.19                15.0       5612.0          1283.0
# 1    -114.47     34.40                19.0       7650.0          1901.0
# 2    -114.56     33.69                17.0        720.0           174.0
# 3    -114.57     33.64                14.0       1501.0           337.0
# 4    -114.57     33.57                20.0       1454.0           326.0
#
#    population  households  median_income  median_house_value
# 0      1015.0       472.0         1.4936             66900.0
# 1      1129.0       463.0         1.8200             80100.0
# 2       333.0       117.0         1.6509             85700.0
# 3       515.0       226.0         3.1917             73400.0
# 4       624.0       262.0         1.9250             65500.0

# %% [markdown]
# #### **ATIVIDADE 2:** Use a função head passando um valor inteiro como parâmetro.

# %%
# seu código aqui
df_housing.head(10)
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -114.31     34.19                15.0       5612.0          1283.0
# 1    -114.47     34.40                19.0       7650.0          1901.0
# 2    -114.56     33.69                17.0        720.0           174.0
# 3    -114.57     33.64                14.0       1501.0           337.0
# 4    -114.57     33.57                20.0       1454.0           326.0
# 5    -114.58     33.63                29.0       1387.0           236.0
# 6    -114.58     33.61                25.0       2907.0           680.0
# 7    -114.59     34.83                41.0        812.0           168.0
# 8    -114.59     33.61                34.0       4789.0          1175.0
# 9    -114.60     34.83                46.0       1497.0           309.0
#
#    population  households  median_income  median_house_value
# 0      1015.0       472.0         1.4936             66900.0
# 1      1129.0       463.0         1.8200             80100.0
# 2       333.0       117.0         1.6509             85700.0
# 3       515.0       226.0         3.1917             73400.0
# 4       624.0       262.0         1.9250             65500.0
# 5       671.0       239.0         3.3438             74000.0
# 6      1841.0       633.0         2.6768             82400.0
# 7       375.0       158.0         1.7083             48500.0
# 8      3134.0      1056.0         2.1782             58400.0
# 9       787.0       271.0         2.1908             48100.0

# %% [markdown]
# #### Função `describe()`

# %%
df_housing.describe()
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  17000.000000  17000.000000        17000.000000  17000.000000
# mean    -119.562108     35.625225           28.589353   2643.664412
# std        2.005166      2.137340           12.586937   2179.947071
# min     -124.350000     32.540000            1.000000      2.000000
# 25%     -121.790000     33.930000           18.000000   1462.000000
# 50%     -118.490000     34.250000           29.000000   2127.000000
# 75%     -118.000000     37.720000           37.000000   3151.250000
# max     -114.310000     41.950000           52.000000  37937.000000
#
#        total_bedrooms    population    households  median_income  \
# count    17000.000000  17000.000000  17000.000000   17000.000000
# mean       539.410824   1429.573941    501.221941       3.883578
# std        421.499452   1147.852959    384.520841       1.908157
# min          1.000000      3.000000      1.000000       0.499900
# 25%        297.000000    790.000000    282.000000       2.566375
# 50%        434.000000   1167.000000    409.000000       3.544600
# 75%        648.250000   1721.000000    605.250000       4.767000
# max       6445.000000  35682.000000   6082.000000      15.000100
#
#        median_house_value
# count        17000.000000
# mean        207300.912353
# std         115983.764387
# min          14999.000000
# 25%         119400.000000
# 50%         180400.000000
# 75%         265000.000000
# max         500001.000000

# %% [markdown]
# #### Função `value_counts()`

# %% [markdown]
# Primeiro, vamos carregar um novo dataset (Toy Dataset).
#
# Baixe o CSV [neste link](https://drive.google.com/file/d/1ArGT0_cisUUh3QXW9tYM39azFQZDUnow/view?usp=sharing) e depois faça upload para o sistema de arquivos aqui do Colab (estes arquivos só ficam disponíveis na sessão atual).
#
# Informações sobre o dataset [neste link](https://www.kaggle.com/carlolepelaars/toy-dataset).

# %%
# Se preferir, execute um dos códigos abaixo para fazer o download diretamente aqui (basta remover o comentário e executar)

# Opção 1: caso queira ter o arquivo CSV disponível no sistema de arquivos
# do Colab (que permanecerá disponível para esta sessão)
#
# !wget -O toy_dataset.csv "https://docs.google.com/uc?export=download&id=1ArGT0_cisUUh3QXW9tYM39azFQZDUnow"
df_toy = pd.read_csv('toy_dataset.csv')
df_toy

# Opção 2
# df_toy = pd.read_csv('https://docs.google.com/uc?export=download&id=1ArGT0_cisUUh3QXW9tYM39azFQZDUnow')
# df_toy
# Out:
# --2023-08-03 18:01:28--  https://docs.google.com/uc?export=download&id=1ArGT0_cisUUh3QXW9tYM39azFQZDUnow
# Resolving docs.google.com (docs.google.com)... 173.194.213.113, 173.194.213.101, 173.194.213.138, ...
# Connecting to docs.google.com (docs.google.com)|173.194.213.113|:443... connected.
# HTTP request sent, awaiting response... 303 See Other
# Location: https://doc-08-6g-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/29jn15ollrcof2p989jlpcgj0o5pkedn/1691085675000/12301012272938841923/*/1ArGT0_cisUUh3QXW9tYM39azFQZDUnow?e=download&uuid=349a6721-59be-460d-bc0b-ed1080c92474 [following]
# Warning: wildcards not supported in HTTP.
# --2023-08-03 18:01:28--  https://doc-08-6g-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/29jn15ollrcof2p989jlpcgj0o5pkedn/1691085675000/12301012272938841923/*/1ArGT0_cisUUh3QXW9tYM39azFQZDUnow?e=download&uuid=349a6721-59be-460d-bc0b-ed1080c92474
# Resolving doc-08-6g-docs.googleusercontent.com (doc-08-6g-docs.googleusercontent.com)... 173.194.218.132, 2607:f8b0:400c:c14::84
# Connecting to doc-08-6g-docs.googleusercontent.com (doc-08-6g-docs.googleusercontent.com)|173.194.218.132|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 5735570 (5.5M) [text/csv]
# Saving to: ‘toy_dataset.csv’
#
# toy_dataset.csv     100%[===================>]   5.47M  --.-KB/s    in 0.03s
#
# 2023-08-03 18:01:28 (189 MB/s) - ‘toy_dataset.csv’ saved [5735570/5735570]
#         Number    City  Gender  Age    Income Illness
# 0            1  Dallas    Male   41   40367.0      No
# 1            2  Dallas    Male   54   45084.0      No
# 2            3  Dallas    Male   42   52483.0      No
# 3            4  Dallas    Male   40   40941.0      No
# 4            5  Dallas    Male   46   50289.0      No
# ...        ...     ...     ...  ...       ...     ...
# 149995  149996  Austin    Male   48   93669.0      No
# 149996  149997  Austin    Male   25   96748.0      No
# 149997  149998  Austin    Male   26  111885.0      No
# 149998  149999  Austin    Male   25  111878.0      No
# 149999  150000  Austin  Female   37   87251.0      No
#
# [150000 rows x 6 columns]

# %%
# este trecho não precisa ser executado caso tenha sido executada a Opção 2 acima
df_toy = pd.read_csv('toy_dataset.csv')
df_toy
# Out:
#         Number    City  Gender  Age    Income Illness
# 0            1  Dallas    Male   41   40367.0      No
# 1            2  Dallas    Male   54   45084.0      No
# 2            3  Dallas    Male   42   52483.0      No
# 3            4  Dallas    Male   40   40941.0      No
# 4            5  Dallas    Male   46   50289.0      No
# ...        ...     ...     ...  ...       ...     ...
# 149995  149996  Austin    Male   48   93669.0      No
# 149996  149997  Austin    Male   25   96748.0      No
# 149997  149998  Austin    Male   26  111885.0      No
# 149998  149999  Austin    Male   25  111878.0      No
# 149999  150000  Austin  Female   37   87251.0      No
#
# [150000 rows x 6 columns]

# %% [markdown]
# Executando a função `value_counts()` para uma coluna

# %%
df_toy.value_counts('Age')
# Out:
# Age
# 26    3918
# 64    3879
# 41    3862
# 43    3862
# 54    3838
# 29    3805
# 28    3798
# 27    3790
# 63    3784
# 44    3782
# 36    3780
# 59    3775
# 47    3773
# 37    3771
# 33    3769
# 58    3762
# 49    3762
# 42    3760
# 32    3759
# 52    3753
# 31    3749
# 48    3743
# 40    3740
# 61    3737
# 38    3734
# 57    3732
# 30    3731
# 51    3729
# 53    3724
# 34    3710
# 46    3707
# 50    3692
# 55    3687
# 62    3684
# 39    3675
# 45    3670
# 35    3658
# 56    3602
# 60    3582
# 25    1868
# 65    1864
# dtype: int64

# %% [markdown]
# #### **ATIVIDADE 3:**
#
# a) Execute a função sem especificar nenhuma coluna e observe que não tem muita utilidade (as contagens são 1). Em seguida, execute a função para algum par de atributos que produzam valores úteis de contagem (valores diferentes de 1).

# %%
# seu código aqui
df_toy.value_counts()
# Out:
# Number  City           Gender  Age  Income    Illness
# 1       Dallas         Male    41   40367.0   No         1
# 100013  Los Angeles    Male    52   91822.0   No         1
# 99997   Los Angeles    Female  47   81978.0   No         1
# 99998   Los Angeles    Female  29   92224.0   No         1
# 99999   Los Angeles    Female  38   76069.0   No         1
#                                                         ..
# 50001   New York City  Female  52   90857.0   Yes        1
# 50002   New York City  Male    52   110501.0  No         1
# 50003   New York City  Male    41   104107.0  No         1
# 50004   New York City  Male    33   89608.0   No         1
# 150000  Austin         Female  37   87251.0   No         1
# Length: 150000, dtype: int64

# %%
df_toy.value_counts(['City', "Age"])
# Out:
# City             Age
# New York City    28     1328
#                  54     1321
#                  41     1321
#                  36     1312
#                  26     1311
#                         ...
# Boston           25       99
# San Diego        47       92
# Washington D.C.  65       89
# San Diego        25       67
#                  65       55
# Length: 328, dtype: int64

# %% [markdown]
# Mais detalhes sobre a função `value_counts()` [aqui](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.value_counts.html).

# %% [markdown]
# #### Contando os NaN

# %%
df_toy.isna().sum()
# Out:
# Number     0
# City       0
# Gender     0
# Age        0
# Income     0
# Illness    0
# dtype: int64

# %% [markdown]
# ## Plotando gráficos

# %% [markdown]
# #### Histograma (mais detalhes [aqui](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.hist.html))

# %%
df_toy.hist(['Age'])
# Out:
# array([[<Axes: title={'center': 'Age'}>]], dtype=object)

# %% [markdown]
# #### **ATIVIDADE 4:** Execute a função passando uma lista de nomes de colunas e um valor para o parâmetro bins.

# %%
# seu código aqui
df_toy.hist(['Income', 'Age'], bins=40)
# Out:
# array([[<Axes: title={'center': 'Income'}>,
#         <Axes: title={'center': 'Age'}>]], dtype=object)

# %% [markdown]
# #### **ATIVIDADE 5:** Plote um histograma para a coluna `Age` do `DataFrame` `df_toy`, onde o número de bins é o total de idades diferentes existentes no dataset.

# %%
# seu código aqui
df_toy.hist('Age', bins=df_toy['Age'].nunique())
# Out:
# array([[<Axes: title={'center': 'Age'}>]], dtype=object)
