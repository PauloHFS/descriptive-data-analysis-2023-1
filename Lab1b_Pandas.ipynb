# %% [markdown]
# <a href="https://colab.research.google.com/github/PauloHFS/descriptive-data-analysis-2023-1/blob/main/Lab1b_Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Introdução ao Pandas (Parte 2)

# %% [markdown]
# ## Imports

# %%
import pandas as pd

# %% [markdown]
# ## Acessando os Dados
#
# Através de operações de `dict` e `list`

# %%
nome_cidade = pd.Series(['Campina Grande', 'Patos', 'Sousa'])
populacao = pd.Series([399999, 1499999, 99777])

df_city = pd.DataFrame({ 'Nome da Cidade': nome_cidade, 'População': populacao })
df_city
# Out:
#    Nome da Cidade  População
# 0  Campina Grande     399999
# 1           Patos    1499999
# 2           Sousa      99777

# %%
type(df_city['Nome da Cidade'])
# Out:
# pandas.core.series.Series

# %%
df_city['Nome da Cidade']
# Out:
# 0    Campina Grande
# 1             Patos
# 2             Sousa
# Name: Nome da Cidade, dtype: object

# %%
type(df_city['Nome da Cidade'][1])
# Out:
# str

# %%
df_city['Nome da Cidade'][1]
# Out:
# 'Patos'

# %%
df_city[1]['Nome da Cidade'] # erro ?!
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3801             try:
# -> 3802                 return self._engine.get_loc(casted_key)
#    3803             except KeyError as err:
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 1
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-7-c51e595fc28f> in <cell line: 1>()
# ----> 1 df_city[1]['Nome da Cidade'] # erro ?!
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    3805             if self.columns.nlevels > 1:
#    3806                 return self._getitem_multilevel(key)
# -> 3807             indexer = self.columns.get_loc(key)
#    3808             if is_integer(indexer):
#    3809                 indexer = [indexer]
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3802                 return self._engine.get_loc(casted_key)
#    3803             except KeyError as err:
# -> 3804                 raise KeyError(key) from err
#    3805             except TypeError:
#    3806                 # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 1

# %%
type(df_city[0:2])
# Out:
# pandas.core.frame.DataFrame

# %%
df_city[0:2] # filtra as linhas, mantendo todas as colunas
# Out:
#    Nome da Cidade  População
# 0  Campina Grande     399999
# 1           Patos    1499999

# %%
df_city[0:1][0:2] # o que acontece aqui?
# Out:
#    Nome da Cidade  População
# 0  Campina Grande     399999

# %%
df_city['Nome da Cidade'] # filtra as colunas, mantendo todas as linhas
# Out:
# 0    Campina Grande
# 1             Patos
# 2             Sousa
# Name: Nome da Cidade, dtype: object

# %%
df_city[['Nome da Cidade', 'População']][0:2] # filtra as colunas, filtra as linhas
# Out:
#    Nome da Cidade  População
# 0  Campina Grande     399999
# 1           Patos    1499999

# %%
df_city[0:2][['Nome da Cidade', 'População']] # filtra as colunas, filtra as linhas (mesmo efeito do anterior)
# Out:
#    Nome da Cidade  População
# 0  Campina Grande     399999
# 1           Patos    1499999

# %% [markdown]
# #### **ATIVIDADE 6:** a função `value_counts()` só tem o parâmetro `bins` em `Series`, não tem em `DataFrame`. Escreva abaixo um código que processa o `DataFrame` `df_toy`, extraindo uma `Series` que corresponde a uma coluna com valores contínuos (apenas os 100 primeiros elementos da Serie) e aplique `value_counts()` com o parâmetro `bins` igual a 5 para ver o efeito.
#
# Mais informações sobre a função `value_counts()` em `Series` podem ser encontradas [aqui](https://pandas.pydata.org/docs/reference/api/pandas.Series.value_counts.html#pandas.Series.value_counts).

# %%
# Caso precise realizar novamente o download e recarregar o dataframe toy_df, basta executar o código abaixo

# Opção 1: caso queira ter o arquivo CSV disponível no sistema de arquivos
# do Colab (que permanecerá disponível para esta sessão)
#
# !wget -O toy_dataset.csv "https://docs.google.com/uc?export=download&id=1ArGT0_cisUUh3QXW9tYM39azFQZDUnow"
df_toy = pd.read_csv('toy_dataset.csv')
df_toy

# Opção 2
# df_toy = pd.read_csv('https://docs.google.com/uc?export=download&id=1ArGT0_cisUUh3QXW9tYM39azFQZDUnow')
# df_toy
# Out:
# --2023-08-04 02:25:36--  https://docs.google.com/uc?export=download&id=1ArGT0_cisUUh3QXW9tYM39azFQZDUnow
# Resolving docs.google.com (docs.google.com)... 108.177.12.113, 108.177.12.101, 108.177.12.102, ...
# Connecting to docs.google.com (docs.google.com)|108.177.12.113|:443... connected.
# HTTP request sent, awaiting response... 303 See Other
# Location: https://doc-08-6g-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/p5npdfdtr252lmetaub5g72j9qfqhcs0/1691115900000/12301012272938841923/*/1ArGT0_cisUUh3QXW9tYM39azFQZDUnow?e=download&uuid=deeadac6-fb86-49ae-a396-2c1839b08ff3 [following]
# Warning: wildcards not supported in HTTP.
# --2023-08-04 02:25:37--  https://doc-08-6g-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/p5npdfdtr252lmetaub5g72j9qfqhcs0/1691115900000/12301012272938841923/*/1ArGT0_cisUUh3QXW9tYM39azFQZDUnow?e=download&uuid=deeadac6-fb86-49ae-a396-2c1839b08ff3
# Resolving doc-08-6g-docs.googleusercontent.com (doc-08-6g-docs.googleusercontent.com)... 173.194.218.132, 2607:f8b0:400c:c14::84
# Connecting to doc-08-6g-docs.googleusercontent.com (doc-08-6g-docs.googleusercontent.com)|173.194.218.132|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 5735570 (5.5M) [text/csv]
# Saving to: ‘toy_dataset.csv’
#
# toy_dataset.csv     100%[===================>]   5.47M  --.-KB/s    in 0.04s
#
# 2023-08-04 02:25:37 (135 MB/s) - ‘toy_dataset.csv’ saved [5735570/5735570]
#         Number    City  Gender  Age    Income Illness
# 0            1  Dallas    Male   41   40367.0      No
# 1            2  Dallas    Male   54   45084.0      No
# 2            3  Dallas    Male   42   52483.0      No
# 3            4  Dallas    Male   40   40941.0      No
# 4            5  Dallas    Male   46   50289.0      No
# ...        ...     ...     ...  ...       ...     ...
# 149995  149996  Austin    Male   48   93669.0      No
# 149996  149997  Austin    Male   25   96748.0      No
# 149997  149998  Austin    Male   26  111885.0      No
# 149998  149999  Austin    Male   25  111878.0      No
# 149999  150000  Austin  Female   37   87251.0      No
#
# [150000 rows x 6 columns]

# %%
# seu código aqui (solução da atividade)
df_toy['Age'][0:100].value_counts(bins=5)
# Out:
# (40.6, 48.4]                  34
# (56.2, 64.0]                  20
# (24.959999999999997, 32.8]    16
# (32.8, 40.6]                  16
# (48.4, 56.2]                  14
# Name: Age, dtype: int64

# %% [markdown]
# #### **ATIVIDADE 7:** Caso seus bins da questão anterior estejam desordenados. Escreva um código modificado que os exibe ordenados, para facilitar a análise.
#
# Saída esperada:
#
# ```
# (16115.5, 26667.8]     6
# (26667.8, 37167.6]    21
# (37167.6, 47667.4]    27
# (47667.4, 58167.2]    36
# (58167.2, 68667.0]    10
# Name: Income, dtype: int64
# ```
#
# Dica: busque na [documentação de Pandas Series](https://pandas.pydata.org/docs/reference/series.html) uma função que realiza a ordenação:

# %%
# seu código aqui
df_toy['Age'][0:100].value_counts(bins=5).sort_index()
# Out:
# (24.959999999999997, 32.8]    16
# (32.8, 40.6]                  16
# (40.6, 48.4]                  34
# (48.4, 56.2]                  14
# (56.2, 64.0]                  20
# Name: Age, dtype: int64

# %% [markdown]
# ## Acessando com loc e iloc

# %% [markdown]
# Vamos criar um novo `data_frame`

# %%
data_clima = [
              [25, 76.2, 1.0, 'Chuvoso'],
              [27, 76.2, 0.1, 'Chuvoso'],
              [28, 44.2, 1.1, 'Ensolarado'],
              [27, 56.2, 0.25, 'Nublado'],
              [23, 77.2, 1.1, 'Chuvoso']
            ]

df_clima = pd.DataFrame(data_clima,
                       columns=['Temperatura','Umidade','Precipitacao', 'Tempo'],
                       index=['Segunda-feira','Terça-feira','Quarta-feira', 'Quinta-feira', 'Sexta-feira']
                       )
df_clima
# Out:
#                Temperatura  Umidade  Precipitacao       Tempo
# Segunda-feira           25     76.2          1.00     Chuvoso
# Terça-feira             27     76.2          0.10     Chuvoso
# Quarta-feira            28     44.2          1.10  Ensolarado
# Quinta-feira            27     56.2          0.25     Nublado
# Sexta-feira             23     77.2          1.10     Chuvoso

# %%
df_clima.loc['Segunda-feira']
# Out:
# Temperatura          25
# Umidade            76.2
# Precipitacao        1.0
# Tempo           Chuvoso
# Name: Segunda-feira, dtype: object

# %%
type(df_clima.loc['Segunda-feira'])
# Out:
# pandas.core.series.Series

# %%
df_clima.loc[0] #erro
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3801             try:
# -> 3802                 return self._engine.get_loc(casted_key)
#    3803             except KeyError as err:
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 0
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-21-74fee24a8688> in <cell line: 1>()
# ----> 1 df_clima.loc[0] #erro
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1071
#    1072             maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1073             return self._getitem_axis(maybe_callable, axis=axis)
#    1074
#    1075     def _is_scalar_access(self, key: tuple):
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1310         # fall thru to straight lookup
#    1311         self._validate_key(key, axis)
# -> 1312         return self._get_label(key, axis=axis)
#    1313
#    1314     def _get_slice_axis(self, slice_obj: slice, axis: int):
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexing.py in _get_label(self, label, axis)
#    1258     def _get_label(self, label, axis: int):
#    1259         # GH#5567 this will fail if the label is not present in the axis.
# -> 1260         return self.obj.xs(label, axis=axis)
#    1261
#    1262     def _handle_lowerdim_multi_index_axis0(self, tup: tuple):
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in xs(self, key, axis, level, drop_level)
#    4054                     new_index = index[loc]
#    4055         else:
# -> 4056             loc = index.get_loc(key)
#    4057
#    4058             if isinstance(loc, np.ndarray):
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3802                 return self._engine.get_loc(casted_key)
#    3803             except KeyError as err:
# -> 3804                 raise KeyError(key) from err
#    3805             except TypeError:
#    3806                 # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 0

# %%
df_clima.iloc[0] #OK

# %%
type(df_clima.iloc[0])
# Out:
# pandas.core.series.Series

# %%
df_toy.loc[0] #erro ou OK?
# Out:
# Number           1
# City        Dallas
# Gender        Male
# Age             41
# Income     40367.0
# Illness         No
# Name: 0, dtype: object

# %%
df_clima.loc[['Quinta-feira'], ['Umidade']]
# Out:
#               Umidade
# Quinta-feira     56.2

# %%
df_clima.iloc[3, 1]
# Out:
# 56.2

# %%
df_clima.loc[['Segunda-feira','Terça-feira','Quinta-feira']] # seleciona determinadas linhas
# Out:
#                Temperatura  Umidade  Precipitacao    Tempo
# Segunda-feira           25     76.2          1.00  Chuvoso
# Terça-feira             27     76.2          0.10  Chuvoso
# Quinta-feira            27     56.2          0.25  Nublado

# %%
df_clima.iloc[[0,1,3]] # seleciona determinadas linhas
# Out:
#                Temperatura  Umidade  Precipitacao    Tempo
# Segunda-feira           25     76.2          1.00  Chuvoso
# Terça-feira             27     76.2          0.10  Chuvoso
# Quinta-feira            27     56.2          0.25  Nublado

# %%
df_clima.loc[['Segunda-feira','Terça-feira','Quinta-feira'],['Temperatura', 'Tempo']] # algumas linhas e algumas colunas
# Out:
#                Temperatura    Tempo
# Segunda-feira           25  Chuvoso
# Terça-feira             27  Chuvoso
# Quinta-feira            27  Nublado

# %%
df_clima.iloc[[0,1,3],[0,3]] # algumas linhas e algumas colunas
# Out:
#                Temperatura    Tempo
# Segunda-feira           25  Chuvoso
# Terça-feira             27  Chuvoso
# Quinta-feira            27  Nublado

# %%
df_clima.iloc[:, 0] #todas as linhas de uma coluna
# Out:
# Segunda-feira    25
# Terça-feira      27
# Quarta-feira     28
# Quinta-feira     27
# Sexta-feira      23
# Name: Temperatura, dtype: int64

# %%
df_clima.loc[:, ['Temperatura', 'Tempo']] #todas as linhas de determinadas colunas
# Out:
#                Temperatura       Tempo
# Segunda-feira           25     Chuvoso
# Terça-feira             27     Chuvoso
# Quarta-feira            28  Ensolarado
# Quinta-feira            27     Nublado
# Sexta-feira             23     Chuvoso

# %%
df_clima.iloc[:, [0,2]] #todas as linhas de determinadas colunas
# Out:
#                Temperatura  Precipitacao
# Segunda-feira           25          1.00
# Terça-feira             27          0.10
# Quarta-feira            28          1.10
# Quinta-feira            27          0.25
# Sexta-feira             23          1.10

# %% [markdown]
# #### **ATIVIDADE 8:**
#
# (a) escreva um código para recuperar um df contendo as linhas segunda-feira e quarta-feira, com todas as colunas, utilizando `iloc`.
#
# (b) escreva um código equivalente usando `loc`.

# %%
# (a) seu código aqui

df_clima.iloc[:3]
# Out:
#                Temperatura  Umidade  Precipitacao       Tempo
# Segunda-feira           25     76.2           1.0     Chuvoso
# Terça-feira             27     76.2           0.1     Chuvoso
# Quarta-feira            28     44.2           1.1  Ensolarado

# %%
# (b) seu código aqui

df_clima.loc[df_clima.index[:3]]
# Out:
#                Temperatura  Umidade  Precipitacao       Tempo
# Segunda-feira           25     76.2           1.0     Chuvoso
# Terça-feira             27     76.2           0.1     Chuvoso
# Quarta-feira            28     44.2           1.1  Ensolarado

# %% [markdown]
# ## Acessando com slice
#
# Formato start:stop:step

# %%
# sem step
linhas=[0,4]
df_clima.iloc[linhas, 1:3]
# Out:
#                Umidade  Precipitacao
# Segunda-feira     76.2           1.0
# Sexta-feira       77.2           1.1

# %%
# com step nas linhas
df_clima.iloc[0:5:2, 0:3]
# Out:
#                Temperatura  Umidade  Precipitacao
# Segunda-feira           25     76.2           1.0
# Quarta-feira            28     44.2           1.1
# Sexta-feira             23     77.2           1.1

# %%
# Usando labels (com .loc[])
df_clima.loc['Segunda-feira':'Sexta-feira':2, 'Temperatura':'Umidade']
# Out:
#                Temperatura  Umidade
# Segunda-feira           25     76.2
# Quarta-feira            28     44.2
# Sexta-feira             23     77.2

# %% [markdown]
# ## Seleção com expressões booleanas

# %%
st = df_clima['Temperatura']
st
# Out:
# Segunda-feira    25
# Terça-feira      27
# Quarta-feira     28
# Quinta-feira     27
# Sexta-feira      23
# Name: Temperatura, dtype: int64

# %%
st[st>26]
# Out:
# Terça-feira     27
# Quarta-feira    28
# Quinta-feira    27
# Name: Temperatura, dtype: int64

# %%
df_clima2 = df_clima[['Temperatura', 'Umidade', 'Precipitacao']]
df_clima2
# Out:
#                Temperatura  Umidade  Precipitacao
# Segunda-feira           25     76.2          1.00
# Terça-feira             27     76.2          0.10
# Quarta-feira            28     44.2          1.10
# Quinta-feira            27     56.2          0.25
# Sexta-feira             23     77.2          1.10

# %%
df_clima2[df_clima2 > 1]
# Out:
#                Temperatura  Umidade  Precipitacao
# Segunda-feira           25     76.2           NaN
# Terça-feira             27     76.2           NaN
# Quarta-feira            28     44.2           1.1
# Quinta-feira            27     56.2           NaN
# Sexta-feira             23     77.2           1.1

# %%
df_clima2[df_clima2['Temperatura'] > 26]
# Out:
#               Temperatura  Umidade  Precipitacao
# Terça-feira            27     76.2          0.10
# Quarta-feira           28     44.2          1.10
# Quinta-feira           27     56.2          0.25

# %%
df_clima2[(df_clima2['Temperatura'] > 26) & (df_clima2['Precipitacao'] < 1)] # erro se não usar parênteses
# Out:
#               Temperatura  Umidade  Precipitacao
# Terça-feira            27     76.2          0.10
# Quinta-feira           27     56.2          0.25

# %%
df_clima2.query('Temperatura > 26 & Precipitacao < 1')
# Out:
#               Temperatura  Umidade  Precipitacao
# Terça-feira            27     76.2          0.10
# Quinta-feira           27     56.2          0.25

# %%
df_clima[df_clima['Tempo'] == 'Nublado']['Temperatura']
# Out:
# Quinta-feira    27
# Name: Temperatura, dtype: int64

# %%
df_clima['Temperatura'][df_clima['Tempo'] == 'Nublado']
# Out:
# Quinta-feira    27
# Name: Temperatura, dtype: int64

# %%
df_clima[df_clima['Tempo'].str.startswith('C')]
# Out:
#                Temperatura  Umidade  Precipitacao    Tempo
# Segunda-feira           25     76.2           1.0  Chuvoso
# Terça-feira             27     76.2           0.1  Chuvoso
# Sexta-feira             23     77.2           1.1  Chuvoso

# %%
df_clima[df_clima['Tempo'].isin(['Chuvoso', 'Ensolarado'])]
# Out:
#                Temperatura  Umidade  Precipitacao       Tempo
# Segunda-feira           25     76.2           1.0     Chuvoso
# Terça-feira             27     76.2           0.1     Chuvoso
# Quarta-feira            28     44.2           1.1  Ensolarado
# Sexta-feira             23     77.2           1.1     Chuvoso

# %% [markdown]
# #### **ATIVIDADE 9:**
#
# Faça filtragem no `df_clima` de forma a retornar a Umidade de todos os registros cuja Temperatura seja 23, 27 ou 28; e o Tempo comece com 'C'.

# %%
# seu código aqui
df_clima[(df_clima['Temperatura'].isin([23, 27, 28])) & (df_clima['Tempo'].str.startswith('C'))]['Umidade']
# Out:
# Terça-feira    76.2
# Sexta-feira    77.2
# Name: Umidade, dtype: float64

# %% [markdown]
# ## Manipulação de Linhas e Colunas (Adição, Remoção, etc)

# %%
# criando o data frame

d = {'primeira coluna' : pd.Series([11, 22, 32], index=['a', 'b', 'c']),
   'segunda coluna' : pd.Series([11, 22, 33, 44], index=['a', 'b', 'c', 'd'])}

df = pd.DataFrame(d)

# %%
# adicionando nova coluna
df['terceira coluna']=pd.Series([100,200,300],index=['a','b','c'])
df
# Out:
#    primeira coluna  segunda coluna  terceira coluna
# a             11.0              11            100.0
# b             22.0              22            200.0
# c             32.0              33            300.0
# d              NaN              44              NaN

# %%
# criando coluna a partir de outras existentes

df['quarta coluna'] = df['primeira coluna'] + df['terceira coluna']
df
# Out:
#    primeira coluna  segunda coluna  terceira coluna  quarta coluna
# a             11.0              11            100.0          111.0
# b             22.0              22            200.0          222.0
# c             32.0              33            300.0          332.0
# d              NaN              44              NaN            NaN

# %%
# removendo uma coluna

df.pop('quarta coluna')
df
# Out:
#    primeira coluna  segunda coluna  terceira coluna
# a             11.0              11            100.0
# b             22.0              22            200.0
# c             32.0              33            300.0
# d              NaN              44              NaN

# %%
df.drop('a')
# Out:
#    primeira coluna  segunda coluna  terceira coluna
# b             22.0              22            200.0
# c             32.0              33            300.0
# d              NaN              44              NaN

# %%
df # o que aconteceu ?
# Out:
#    primeira coluna  segunda coluna  terceira coluna
# a             11.0              11            100.0
# b             22.0              22            200.0
# c             32.0              33            300.0
# d              NaN              44              NaN

# %%
# drop também pode ser usado para colunas
df = df.drop('segunda coluna', axis=1)
df
# Out:
#    primeira coluna  terceira coluna
# a             11.0            100.0
# b             22.0            200.0
# c             32.0            300.0
# d              NaN              NaN

# %%
df2 = pd.DataFrame([[50, 60], [70, 80]], columns = ['primeira coluna','terceira coluna'])
df = df.append(df2)
df
# Out:
# <ipython-input-57-f905957e8d93>:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df2)
#    primeira coluna  terceira coluna
# a             11.0            100.0
# b             22.0            200.0
# c             32.0            300.0
# d              NaN              NaN
# 0             50.0             60.0
# 1             70.0             80.0

# %%
df2 = pd.DataFrame([[90, 99], [66, 88]], columns = ['primeira coluna','segunda coluna'])
df = df.append(df2)
df
# Out:
# <ipython-input-72-1620b2e00ecb>:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df2)
#    primeira coluna  terceira coluna  segunda coluna
# a             11.0            100.0             NaN
# b             22.0            200.0             NaN
# c             32.0            300.0             NaN
# d              NaN              NaN             NaN
# 0             50.0             60.0             NaN
# 1             70.0             80.0             NaN
# 0             90.0              NaN            99.0
# 1             66.0              NaN            88.0
# 0             90.0              NaN            99.0
# 1             66.0              NaN            88.0
# 0             90.0              NaN            99.0
# 1             66.0              NaN            88.0

# %% [markdown]
# ####**ATIVIDADE 10:**
#
# O dataframe da célula anterior ficou com as colunas bagunçadas (primeira/terceira/segunda).
#
# a) Reorganize as colunas.
#
# b) O índice das linhas também ficaram bagunçados! Reorganize-os também para ficar com numeração 0,1,2,...,n. Dica: use o método reset_index(). Depois de usar o método, veja se o dataframe ficou da forma que você esperava. Se não tiver ficado, ajuste-o.

# %%
# a) seu código aqui
df = df[['primeira coluna', 'segunda coluna', 'terceira coluna']]
df
# Out:
#    primeira coluna  segunda coluna  terceira coluna
# a             11.0             NaN            100.0
# b             22.0             NaN            200.0
# c             32.0             NaN            300.0
# d              NaN             NaN              NaN
# 0             50.0             NaN             60.0
# 1             70.0             NaN             80.0
# 0             90.0            99.0              NaN
# 1             66.0            88.0              NaN
# 0             90.0            99.0              NaN
# 1             66.0            88.0              NaN
# 0             90.0            99.0              NaN
# 1             66.0            88.0              NaN

# %%
# b) seu código aqui
df.reset_index().drop('index', axis=1)
# Out:
#     primeira coluna  segunda coluna  terceira coluna
# 0              11.0             NaN            100.0
# 1              22.0             NaN            200.0
# 2              32.0             NaN            300.0
# 3               NaN             NaN              NaN
# 4              50.0             NaN             60.0
# 5              70.0             NaN             80.0
# 6              90.0            99.0              NaN
# 7              66.0            88.0              NaN
# 8              90.0            99.0              NaN
# 9              66.0            88.0              NaN
# 10             90.0            99.0              NaN
# 11             66.0            88.0              NaN

# %% [markdown]
# Isso é só um pouquinho do que o Pandas oferece no que se trata de indexação e seleção. A API do pandas é muito vasta em relação a isso.
# Para mais informações, [veja aqui](https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html).
